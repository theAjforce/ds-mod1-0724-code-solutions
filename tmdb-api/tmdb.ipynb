# %%
import requests
import pandas as pd
import json
import tmdbsimple as tmdb

# %%
api_key = "69e0d756f57f03c3427c9622298bc4dc"
url = f"https://api.themoviedb.org/3/search/movie?api_key={api_key}"

# %%
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
starwars_url = url + "&query=Star%20Wars"

# %%
starwars_data = requests.get(starwars_url)
total_pages = starwars_data.json()['total_pages']

# %%
all_starwars = []
for page_num in range(total_pages):
    page_url = starwars_url + f"&page={page_num+1}"
    get_request = requests.get(page_url)
    allswjson = get_request.json()['results']
    all_starwars += (allswjson)

all_starwars
# Out:
# [{'adult': False,
#   'backdrop_path': '/jNjT5y95BToczcxgVPl1NBB7goY.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 11,
#   'original_language': 'en',
#   'original_title': 'Star Wars',
#   'overview': 'Princess Leia is captured and held hostage by the evil Imperial forces in their effort to take over the galactic Empire. Venturesome Luke Skywalker and dashing captain Han Solo team together with the loveable robot duo R2-D2 and C-3PO to rescue the beautiful princess and restore peace and justice in the Empire.',
#   'popularity': 143.146,
#   'poster_path': '/6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg',
#   'release_date': '1977-05-25',
#   'title': 'Star Wars',
#   'video': False,
#   'vote_average': 8.203,
#   'vote_count': 20283},
#  {'adult': False,
#   'backdrop_path': '/k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 140607,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Force Awakens',
#   'overview': 'Thirty years after defeating the Galactic Empire, Han Solo and his allies face a new threat from the evil Kylo Ren and his army of Stormtroopers.',
#   'popularity': 90.923,
#   'poster_path': '/wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg',
#   'release_date': '2015-12-15',
#   'title': 'Star Wars: The Force Awakens',
#   'video': False,
#   'vote_average': 7.278,
#   'vote_count': 19090},
#  {'adult': False,
#   'backdrop_path': '/epVMXf10WqFkONzKR8V76Ypj5Y3.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 181808,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Last Jedi',
#   'overview': 'Rey develops her newly discovered abilities with the guidance of Luke Skywalker, who is unsettled by the strength of her powers. Meanwhile, the Resistance prepares to do battle with the First Order.',
#   'popularity': 82.35,
#   'poster_path': '/kOVEVeg59E0wsnXmF9nrh6OmWII.jpg',
#   'release_date': '2017-12-13',
#   'title': 'Star Wars: The Last Jedi',
#   'video': False,
#   'vote_average': 6.799,
#   'vote_count': 15010},
#  {'adult': False,
#   'backdrop_path': '/ojHCeDULAkQK25700fhRU75Tur2.jpg',
#   'genre_ids': [878, 12, 28],
#   'id': 348350,
#   'original_language': 'en',
#   'original_title': 'Solo: A Star Wars Story',
#   'overview': 'Through a series of daring escapades deep within a dark and dangerous criminal underworld, Han Solo meets his mighty future copilot Chewbacca and encounters the notorious gambler Lando Calrissian.',
#   'popularity': 51.576,
#   'poster_path': '/4oD6VEccFkorEBTEDXtpLAaz0Rl.jpg',
#   'release_date': '2018-05-15',
#   'title': 'Solo: A Star Wars Story',
#   'video': False,
#   'vote_average': 6.562,
#   'vote_count': 8345},
#  {'adult': False,
#   'backdrop_path': '/jn52me8AagfNt7r84SgQbV0R9ZG.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 181812,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Rise of Skywalker',
#   'overview': 'The surviving Resistance faces the First Order once again as the journey of Rey, Finn and Poe Dameron continues. With the power and knowledge of generations behind them, the final battle begins.',
#   'popularity': 82.393,
#   'poster_path': '/db32LaOibwEliAmSL2jjDF6oDdj.jpg',
#   'release_date': '2019-12-18',
#   'title': 'Star Wars: The Rise of Skywalker',
#   'video': False,
#   'vote_average': 6.326,
#   'vote_count': 9676},
#  {'adult': False,
#   'backdrop_path': '/8mTHUXS3vwub5ZlovQkZ8veQUah.jpg',
#   'genre_ids': [28, 12, 878],
#   'id': 330459,
#   'original_language': 'en',
#   'original_title': 'Rogue One: A Star Wars Story',
#   'overview': 'A rogue band of resistance fighters unite for a mission to steal the Death Star plans and bring a new hope to the galaxy.',
#   'popularity': 60.318,
#   'poster_path': '/i0yw1mFbB7sNGHCs7EXZPzFkdA1.jpg',
#   'release_date': '2016-12-14',
#   'title': 'Rogue One: A Star Wars Story',
#   'video': False,
#   'vote_average': 7.493,
#   'vote_count': 15007},
#  {'adult': False,
#   'backdrop_path': '/aQX9Hc4pCdbkzf4Oz6FMSpujagV.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 1895,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Episode III - Revenge of the Sith',
#   'overview': 'The evil Darth Sidious enacts his final plan for unlimited power -- and the heroic Jedi Anakin Skywalker must choose a side.',
#   'popularity': 57.244,
#   'poster_path': '/xfSAoBEm9MNBjmlNcDYLvLSMlnq.jpg',
#   'release_date': '2005-05-17',
#   'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'video': False,
#   'vote_average': 7.43,
#   'vote_count': 13457},
#  {'adult': False,
#   'backdrop_path': '/f53Jujiap580mgfefID0T0g2e17.jpg',
#   'genre_ids': [16, 10751, 878, 35, 10770],
#   'id': 857702,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars Terrifying Tales',
#   'overview': 'Poe Dameron and BB-8 must face the greedy crime boss Graballa the Hutt, who has purchased Darth Vader’s castle and is renovating it into the galaxy’s first all-inclusive Sith-inspired luxury hotel.',
#   'popularity': 28.624,
#   'poster_path': '/fYiaBZDjyXjvlY6EDZMAxIhBO1I.jpg',
#   'release_date': '2021-10-01',
#   'title': 'LEGO Star Wars Terrifying Tales',
#   'video': False,
#   'vote_average': 6.802,
#   'vote_count': 239},
#  {'adult': False,
#   'backdrop_path': '/3TeGmKJfkik1D1rIoqGb1aR4k9c.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 1893,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Episode I - The Phantom Menace',
#   'overview': 'Anakin Skywalker, a young slave strong with the Force, is discovered on Tatooine. Meanwhile, the evil Sith have returned, enacting their plot for revenge against the Jedi.',
#   'popularity': 63.342,
#   'poster_path': '/6wkfovpn7Eq8dYNKaG5PY3q2oq6.jpg',
#   'release_date': '1999-05-19',
#   'title': 'Star Wars: Episode I - The Phantom Menace',
#   'video': False,
#   'vote_average': 6.553,
#   'vote_count': 14348},
#  {'adult': False,
#   'backdrop_path': '/iflKt34Ck2JpY2PY9wW1zwdJgJi.jpg',
#   'genre_ids': [16, 878, 12, 10751],
#   'id': 782054,
#   'original_language': 'ja',
#   'original_title': '映画ドラえもん のび太の宇宙小戦争 2021',
#   'overview': 'One day during summer vacation, a palm-sized alien named Papi appears from a small rocket that Nobita picks up. He is the president of Pirika, a small planet in outer space, and has come to Earth to escape the rebels. Doraemon and his friends are puzzled by Papi’s small size, but as they play together using the secret tool “Small Light”, they gradually become friends. However, a whale-shaped space battleship comes to earth and attacks Doraemon, Nobita and the others in order to capture Papi. Feeling responsible for getting everyone involved, Papi tries to stand up to the rebels. Doraemon and his friends leave for the planet Pirika to protect their dear friend and his home.',
#   'popularity': 25.898,
#   'poster_path': '/48gKZioIDeUOI0afbYv3kh9u9RQ.jpg',
#   'release_date': '2022-03-04',
#   'title': "Doraemon the Movie: Nobita's Little Star Wars 2021",
#   'video': False,
#   'vote_average': 5.9,
#   'vote_count': 106},
#  {'adult': False,
#   'backdrop_path': '/abwxHfymXGAbbH3lo9PDEJEfvtW.jpg',
#   'genre_ids': [12, 28, 878],
#   'id': 1894,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Episode II - Attack of the Clones',
#   'overview': 'Following an assassination attempt on Senator Padmé Amidala, Jedi Knights Anakin Skywalker and Obi-Wan Kenobi investigate a mysterious plot that could change the galaxy forever.',
#   'popularity': 49.747,
#   'poster_path': '/oZNPzxqM2s5DyVWab09NTQScDQt.jpg',
#   'release_date': '2002-05-15',
#   'title': 'Star Wars: Episode II - Attack of the Clones',
#   'video': False,
#   'vote_average': 6.565,
#   'vote_count': 12990},
#  {'adult': False,
#   'backdrop_path': '/wBBONMlfnrU2GxxN7X2pFDdZuRB.jpg',
#   'genre_ids': [16, 12, 10751, 14, 878],
#   'id': 161704,
#   'original_language': 'ja',
#   'original_title': 'ドラえもん のび太の宇宙小戦争',
#   'overview': 'Nobita helps Doraemon to create a space movie. After Dekisugi fails to help them, the duo rope in Shizuka, who prefers to make a film about dolls.',
#   'popularity': 17.096,
#   'poster_path': '/n4IPqrfXEEtMC8hzV5PaCElkdNP.jpg',
#   'release_date': '1985-03-16',
#   'title': "Doraemon: Nobita's Little Star Wars",
#   'video': False,
#   'vote_average': 6.878,
#   'vote_count': 37},
#  {'adult': False,
#   'backdrop_path': '/eVA4ztLIuPEsokkgQ3NRt9rTRVh.jpg',
#   'genre_ids': [16, 28, 878, 12],
#   'id': 12180,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Clone Wars',
#   'overview': 'As the Clone Wars sweep through the galaxy, the heroic Jedi Knights struggle to maintain order and restore peace. More and more systems are falling prey to the forces of the dark side as the Galactic Republic slips further and further under the sway of the Separatists and their never-ending droid army. Anakin Skywalker and his Padawan learner Ahsoka Tano find themselves on a mission with far-reaching consequences, one that brings them face-to-face with crime lord Jabba the Hutt. But Count Dooku and his sinister agents, including the nefarious Asajj Ventress, will stop at nothing to ensure that Anakin and Ahsoka fail at their quest. Meanwhile, on the front lines of the Clone Wars, Obi-Wan Kenobi and Master Yoda lead the massive clone army in a valiant effort to resist the forces of the dark side...',
#   'popularity': 26.103,
#   'poster_path': '/iJQfixW818LUdSXlCDL3JZm0S0g.jpg',
#   'release_date': '2008-08-05',
#   'title': 'Star Wars: The Clone Wars',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 1958},
#  {'adult': False,
#   'backdrop_path': '/uNjBnOmdjZoiWTLQ938YJZ1cYVU.jpg',
#   'genre_ids': [16, 35, 10751, 878, 12, 10770],
#   'id': 392216,
#   'original_language': 'en',
#   'original_title': 'Phineas and Ferb: Star Wars',
#   'overview': "Phineas and Ferb become the galaxy's unlikeliest last hope when they must return the Death Star plans to the Rebel Alliance.",
#   'popularity': 21.17,
#   'poster_path': '/2XGlp5x232CeZM0PVjMMYQcXViA.jpg',
#   'release_date': '2014-07-26',
#   'title': 'Phineas and Ferb: Star Wars',
#   'video': False,
#   'vote_average': 7.152,
#   'vote_count': 197},
#  {'adult': False,
#   'backdrop_path': '/1Lhc32P0a62BgMFgd20wXR1osR3.jpg',
#   'genre_ids': [16, 10751, 878, 12, 35],
#   'id': 732670,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars Holiday Special',
#   'overview': 'As her friends prep for a Life Day holiday celebration, Rey journeys with BB-8 on a quest to gain a deeper knowledge of the Force at a mysterious Jedi Temple. There, she embarks on a cross-timeline adventure through beloved moments in Star Wars history, coming into contact with iconic heroes and villains from all eras of the saga. But will she make it back in time for the Life Day feast?',
#   'popularity': 21.348,
#   'poster_path': '/zyzJSI7UZZzz5Toj10rYGF5689z.jpg',
#   'release_date': '2020-11-17',
#   'title': 'LEGO Star Wars Holiday Special',
#   'video': False,
#   'vote_average': 6.523,
#   'vote_count': 311},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 432134,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Heroes & Villains',
#   'overview': 'A look at the creation and filming of the various heroes and villains from all six Star Wars movies, leading up to the release of Star Wars: Episode III - Revenge of the Sith.',
#   'popularity': 4.836,
#   'poster_path': '/9ReI6qt3bvsIxUZkDpOzaCpiLwx.jpg',
#   'release_date': '2005-05-03',
#   'title': 'Star Wars: Heroes & Villains',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 20},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 522640,
#   'original_language': 'es',
#   'original_title': 'Criaturas de La guerra de las galaxias',
#   'overview': '',
#   'popularity': 4.362,
#   'poster_path': None,
#   'release_date': '2006-12-12',
#   'title': 'Creatures from Star Wars',
#   'video': False,
#   'vote_average': 4.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/l3OSKCM0oBOGuioC2jeaeeV8m4I.jpg',
#   'genre_ids': [16, 35, 878, 28, 10770],
#   'id': 42979,
#   'original_language': 'en',
#   'original_title': 'Robot Chicken: Star Wars',
#   'overview': 'A series of 30 sketches, following the hilarious antics of various characters from a galaxy, far, far away.',
#   'popularity': 12.216,
#   'poster_path': '/h44WN4mVJ6wEpJgLaaNoFjv0NAo.jpg',
#   'release_date': '2007-07-17',
#   'title': 'Robot Chicken: Star Wars',
#   'video': False,
#   'vote_average': 7.223,
#   'vote_count': 242},
#  {'adult': False,
#   'backdrop_path': '/98CXGiN2bIh6HUnRjFNGgA9o4FZ.jpg',
#   'genre_ids': [99],
#   'id': 956879,
#   'original_language': 'fr',
#   'original_title': 'Dans l’ombre du Star Wars Kid',
#   'overview': 'Ghyslain Raza, better known as the “Star Wars Kid,” breaks his silence to reflect on our hunger for content and the right to be forgotten in the digital age.',
#   'popularity': 2.077,
#   'poster_path': '/zspMlOFJ76g5KyfmucgnvnkJnuN.jpg',
#   'release_date': '2022-03-30',
#   'title': 'Star Wars Kid: The Rise of the Digital Shadows',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 9},
#  {'adult': False,
#   'backdrop_path': '/7nHXstkbnX8t7fKICraMJkuPhK5.jpg',
#   'genre_ids': [14, 878, 10751, 10770],
#   'id': 74849,
#   'original_language': 'en',
#   'original_title': 'The Star Wars Holiday Special',
#   'overview': 'Luke Skywalker and Han Solo battle evil Imperial forces to help Chewbacca reach his imperiled family on the Wookiee planet - in time for Life Day, their most important day of the year!',
#   'popularity': 18.088,
#   'poster_path': '/2X17DnEtlI6ULf95wXC6sA4GrlL.jpg',
#   'release_date': '1978-11-17',
#   'title': 'The Star Wars Holiday Special',
#   'video': False,
#   'vote_average': 3.337,
#   'vote_count': 445},
#  {'adult': False,
#   'backdrop_path': '/vV5knD9jlW8QaOhCgf4129hbIIh.jpg',
#   'genre_ids': [16, 10751, 878, 35, 10770],
#   'id': 980804,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars Summer Vacation',
#   'overview': "Looking for a much-needed break, Finn arranges a surprise vacation for his friends Rey, Poe, Rose, Chewie, BB-8, R2-D2, and C-3PO, aboard the luxurious Halcyon. However, Finn's plan to have one last hurrah together quickly goes awry.",
#   'popularity': 15.565,
#   'poster_path': '/2SatEFCs04oFRqkZuY1fODYXeFI.jpg',
#   'release_date': '2022-08-05',
#   'title': 'LEGO Star Wars Summer Vacation',
#   'video': False,
#   'vote_average': 6.021,
#   'vote_count': 72},
#  {'adult': False,
#   'backdrop_path': '/75fLMqLW9wVwvtl7vTCnnRNaN5M.jpg',
#   'genre_ids': [12, 16, 878, 28, 10770],
#   'id': 337755,
#   'original_language': 'en',
#   'original_title': 'Star Wars Rebels: The Siege of Lothal',
#   'overview': 'The Ghost crew and their allies face Darth Vader for the first time and Ahsoka Tano discovers the true identity of Darth Vader.',
#   'popularity': 12.126,
#   'poster_path': '/cx9lBBCtH0FJSmvgOlKTvETu0so.jpg',
#   'release_date': '2015-04-18',
#   'title': 'Star Wars Rebels: The Siege of Lothal',
#   'video': False,
#   'vote_average': 7.836,
#   'vote_count': 77},
#  {'adult': False,
#   'backdrop_path': '/5lERsrmxhb6ggGQZDHe05qeNCnD.jpg',
#   'genre_ids': [12, 16, 28, 878, 10770, 10751],
#   'id': 287663,
#   'original_language': 'en',
#   'original_title': 'Star Wars Rebels: Spark of Rebellion',
#   'overview': 'Ezra Bridger encounters the Ghost crew and joins them on a mission to free Wookiees from an Imperial Star Destroyer.',
#   'popularity': 13.718,
#   'poster_path': '/ApPuHAhH4wYGb4YCLChJYQvHUEF.jpg',
#   'release_date': '2014-10-03',
#   'title': 'Star Wars Rebels: Spark of Rebellion',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 136},
#  {'adult': False,
#   'backdrop_path': '/7rZrvtpQTrA9B1nqoHNGjsp8j8i.jpg',
#   'genre_ids': [878, 99],
#   'id': 825647,
#   'original_language': 'en',
#   'original_title': 'Star Wars Biomes',
#   'overview': 'Take a virtual vacation to some of the Star Wars films’ most iconic and beloved locations like Hoth, Tatooine, and Sorgan, as this charming series whisks you off for fly-through tours of the Galaxy Far, Far Away.',
#   'popularity': 7.262,
#   'poster_path': '/8I69ReO2IZtcpXnzZpKeswpPI33.jpg',
#   'release_date': '2021-05-04',
#   'title': 'Star Wars Biomes',
#   'video': False,
#   'vote_average': 6.532,
#   'vote_count': 47},
#  {'adult': False,
#   'backdrop_path': '/hVl0qfLZ5loznDgQ0HxCTZqvZhz.jpg',
#   'genre_ids': [10751, 16, 878],
#   'id': 70608,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars: The Padawan Menace',
#   'overview': 'Master Yoda must go retrieve secret battle plans. However, things become a little more complicated when a class of younglings join the mission.',
#   'popularity': 11.548,
#   'poster_path': '/bCDa9memHnETeRrJWXzImTZdMal.jpg',
#   'release_date': '2011-07-22',
#   'title': 'LEGO Star Wars: The Padawan Menace',
#   'video': False,
#   'vote_average': 6.474,
#   'vote_count': 134},
#  {'adult': False,
#   'backdrop_path': '/e3l3MaoCIAyPDPoMs9fRkKeidra.jpg',
#   'genre_ids': [99],
#   'id': 376798,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Evolution of the Lightsaber Duel',
#   'overview': 'Though lightsabers have been a force in the Star Wars galaxy since George Lucas’ original film, the weapon’s on-screen presence evolved throughout both cinematic trilogies and into Star Wars: The Force Awakens. SportsCenter is tracing the lightsaber’s lineage through the films, and a new trailer for the special will definitely delight any fan’s inner Star Wars Kid.',
#   'popularity': 8.701,
#   'poster_path': '/xVeTl156TdJsj7Hsgtqar8ygX1T.jpg',
#   'release_date': '2015-12-15',
#   'title': 'Star Wars: Evolution of the Lightsaber Duel',
#   'video': False,
#   'vote_average': 6.2,
#   'vote_count': 12},
#  {'adult': False,
#   'backdrop_path': '/puuJM5KzLAqxp88erpHRw0fVZx8.jpg',
#   'genre_ids': [99],
#   'id': 76180,
#   'original_language': 'en',
#   'original_title': 'Empire of Dreams: The Story of the Star Wars Trilogy',
#   'overview': 'From the earliest versions of the script to the blockbuster debuts, explore the creation of the Star Wars Trilogy.',
#   'popularity': 16.217,
#   'poster_path': '/xq0MPT1lLxfznTRaAbInxWT2wfh.jpg',
#   'release_date': '2004-09-12',
#   'title': 'Empire of Dreams: The Story of the Star Wars Trilogy',
#   'video': False,
#   'vote_average': 7.729,
#   'vote_count': 179},
#  {'adult': False,
#   'backdrop_path': '/rrQJwg3jFQasEilhmq8TMpGocb1.jpg',
#   'genre_ids': [35, 878, 16, 10770, 28],
#   'id': 51888,
#   'original_language': 'en',
#   'original_title': 'Robot Chicken: Star Wars Episode III',
#   'overview': "Robot Chicken: Star Wars Episode III, directed by Chris McKay, combines the satirical sensibilities of Green and Matthew Senreich's Robot Chicken with characters of the Star Wars universe.",
#   'popularity': 11.199,
#   'poster_path': '/mi2lVho2zpfwcxI6yC1QYJi435D.jpg',
#   'release_date': '2010-12-19',
#   'title': 'Robot Chicken: Star Wars Episode III',
#   'video': False,
#   'vote_average': 7.389,
#   'vote_count': 144},
#  {'adult': False,
#   'backdrop_path': '/c8XIFuJCPTtTJdSRpqnUoMr6eK1.jpg',
#   'genre_ids': [878, 28],
#   'id': 667574,
#   'original_language': 'en',
#   'original_title': 'Battle Star Wars',
#   'overview': 'When the leader of the evil Coalition threatens to destroy a Rebel planet for its resources, his daughter will have no choice but to join the Rebel side and fight for what is right.',
#   'popularity': 6.679,
#   'poster_path': '/ocA0ECiFoB4d1HITyEDQlLk7x84.jpg',
#   'release_date': '2020-01-28',
#   'title': 'Battle Star Wars',
#   'video': False,
#   'vote_average': 4.923,
#   'vote_count': 39},
#  {'adult': False,
#   'backdrop_path': '/aM1dP91YFVPsgq1WG8vMwip9zLe.jpg',
#   'genre_ids': [10751, 16, 878],
#   'id': 136406,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars: The Empire Strikes Out',
#   'overview': "Luke Skywalker embarks on a mission to destroy an Imperial base, but is relentlessly chased by a group of fanatic girls who think of him as a celebrity. Meanwhile, Darth Vader engages a rivalry with Darth Maul, in order to prove that he's the best Sith Lord.",
#   'popularity': 11.895,
#   'poster_path': '/doeFDzZ0Ywp8YUoRaEhVE5UBqka.jpg',
#   'release_date': '2012-09-24',
#   'title': 'LEGO Star Wars: The Empire Strikes Out',
#   'video': False,
#   'vote_average': 6.293,
#   'vote_count': 94},
#  {'adult': False,
#   'backdrop_path': '/nN7nxUReByo0ymvVOnevkJgOghO.jpg',
#   'genre_ids': [16, 10751],
#   'id': 1221254,
#   'original_language': 'en',
#   'original_title': "Star Wars: Ahsoka - Sabine's Loth-Cat",
#   'overview': "Help babysit Sabine's Loth-cat, Murley, while she explores the galaxy. Relax or catnap to Star Wars ambience composed by Kevin Kiner, Sean Kiner, Deana Kiner and Jason Fujita.",
#   'popularity': 4.79,
#   'poster_path': '/9uFYvjOmgn1fTJ0I2BeqQesz7O9.jpg',
#   'release_date': '2023-12-22',
#   'title': "Star Wars: Ahsoka - Sabine's Loth-Cat",
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/oJNrNkSb6NBRlOCplioFQhvR7M4.jpg',
#   'genre_ids': [878, 16, 35],
#   'id': 42982,
#   'original_language': 'en',
#   'original_title': 'Robot Chicken: Star Wars Episode II',
#   'overview': 'Seth Green and Matthew Senreich serve up more hilarious Star Wars-inspired satire in this second compilation of sketches featuring the zany stop-motion animation of Adult Swim\'s "Robot Chicken." Gary the stormtrooper deals with irascible boss Darth Vader on Take Your Daughter to Work Day, while Anakin babysits a certain up-and-coming Jedi.',
#   'popularity': 10.867,
#   'poster_path': '/dM5eCurdAXYd3Dvyr9Rz2YSj3rJ.jpg',
#   'release_date': '2008-11-16',
#   'title': 'Robot Chicken: Star Wars Episode II',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 134},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99, 878],
#   'id': 713695,
#   'original_language': 'en',
#   'original_title': 'Star Wars vs. Star Trek: The Rivalry Continues',
#   'overview': 'For years, STAR WARS fan have squared off against STAR TREK fans over which space fantasy is the better choice. As a result, both franchises have been embroiled in a continuing battle for merchandise sales, publicity and box-office receipts. The science-fiction genre has never seen anything like it and, as these fictional universes continue to expand, the competition seems to be never ending. Star Wars vs. Star Trek: The Rivalry Continues compares the space opera worlds of George Lucas and Gene Roddenberry for a one-of-a-kind intergalactic documentary.',
#   'popularity': 3.961,
#   'poster_path': '/3QjqzSGuH10u2vfvzuvX7e2xQ8L.jpg',
#   'release_date': '2002-01-01',
#   'title': 'Star Wars vs. Star Trek: The Rivalry Continues',
#   'video': False,
#   'vote_average': 1.5,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': '/5xvJgryDkW5S6cLvQ2BjL4lZcKB.jpg',
#   'genre_ids': [16, 28, 12],
#   'id': 184902,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Clone Wars - Darth Maul Returns',
#   'overview': 'After Dathomir falls prey to a merciless attack by General Grievous, Asajj Ventress survives to join a bounty hunter clan led by a young Boba Fett. Meanwhile, the dark warrior Savage Opress returns to his creator, the witch Mother Talzin, who gives him a sinister mission: to search the galaxy for his brother, Sith Apprentice Darth Maul. Believed dead for over a decade after falling to the sword of then Jedi Apprentice Obi-Wan Kenobi, Darth Maul is nearly unrecognizable, residing in the bowels of a ruined planet and fueled by hatred. Savage Opress delivers the shattered Maul to Mother Talzin to restore his former powers, and the brothers vow an oath of vengeance against Obi-Wan Kenobi.',
#   'popularity': 8.431,
#   'poster_path': '/mOtQgGmdNxouIiMLIPUzIe94UbZ.jpg',
#   'release_date': '2012-09-11',
#   'title': 'Star Wars: The Clone Wars - Darth Maul Returns',
#   'video': True,
#   'vote_average': 7.5,
#   'vote_count': 23},
#  {'adult': False,
#   'backdrop_path': '/fDbnJeTZMWUCXHwxuYcDXVmhefM.jpg',
#   'genre_ids': [99, 10770],
#   'id': 72694,
#   'original_language': 'en',
#   'original_title': 'The Making of Star Wars',
#   'overview': 'Learn the incredible behind-the-scenes story of how the original Star Wars  movie was brought to the big screen in this fascinating documentary hosted by C-3PO and R2-D2 which includes interviews with George Lucas and appearances by Mark Hamill, Harrison Ford and Carrie Fisher.',
#   'popularity': 6.44,
#   'poster_path': '/SUuNG1l918uBNMZZRDrUQMvwzt.jpg',
#   'release_date': '1977-09-16',
#   'title': 'The Making of Star Wars',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 37},
#  {'adult': False,
#   'backdrop_path': '/aUxPyo0Olrr6qs33fKkjbX2piYk.jpg',
#   'genre_ids': [35],
#   'id': 515773,
#   'original_language': 'en',
#   'original_title': 'Star Wars Spoofs',
#   'overview': 'The farce is strong with this one! Enjoy a hilarious collection of Star Wars movie scene spoofs and parodies that have been created over the years, including outrageous clips from Family Guy, The Simpsons, How I Met Your Mother, and more - and don\'t miss "Weird Al" Yankovic\'s one-of-a-kind music video tribute to The Phantom Menace!',
#   'popularity': 3.471,
#   'poster_path': '/ApEnrioR2GrkyWVXCrIzDMtgk9b.jpg',
#   'release_date': '2011-01-01',
#   'title': 'Star Wars Spoofs',
#   'video': False,
#   'vote_average': 7.5,
#   'vote_count': 11},
#  {'adult': False,
#   'backdrop_path': '/pPVF3MjemzrHUAmVSfiQQhokO53.jpg',
#   'genre_ids': [99],
#   'id': 765673,
#   'original_language': 'en',
#   'original_title': 'A Disturbance in the Force: How the Star Wars Holiday Special Happened',
#   'overview': 'In 1978, CBS aired the “Star Wars Holiday Special” the week before Thanksgiving to an audience of 13 million people. Considered one of the worst shows in television history, it aired only once. George Lucas tried to bury it and an infamous camp legend was born. This documentary unravels the mysteries behind the most bizarre Star Wars spin-offs of all time.',
#   'popularity': 7.097,
#   'poster_path': '/s1sdJpXOp0HZOeLfL7peA09FTNG.jpg',
#   'release_date': '2023-03-11',
#   'title': 'A Disturbance in the Force: How the Star Wars Holiday Special Happened',
#   'video': False,
#   'vote_average': 6.2,
#   'vote_count': 5},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 533721,
#   'original_language': 'en',
#   'original_title': "The Stories: The Making of 'Rogue One: A Star Wars Story'",
#   'overview': "The Making of 'Rogue One: A Star Wars Story'.",
#   'popularity': 6.16,
#   'poster_path': '/xuI27etRYWk7vP0aCUTTnIfnpC4.jpg',
#   'release_date': '2017-04-04',
#   'title': "The Stories: The Making of 'Rogue One: A Star Wars Story'",
#   'video': False,
#   'vote_average': 5.6,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 435365,
#   'original_language': 'en',
#   'original_title': 'The Story of Star Wars',
#   'overview': 'The Skywalker family is at the heart of the Star Wars saga. Now hear the inside story of Luke and Anakin Skywalker from the characters who witnessed it all: the famous droid duo C-3PO and R2-D2. Episodes IV,V and VI are explored in "The Story of Luke Skywalker," which follows the young man escaping from his daily chores on Tatooine to his becoming a hero in the Rebal Alliance. In "The Story of Anakin Skywalker," you\'ll go behind the mask of the greatest Star Wars villain and discover how Darth Vader started life as a young Podracing Champ on Tatooine and later became a headstrong young Jedi seduced by the Dark Side of the Force. With clips from the Star Wars films, C-3PO and R2-D2 take you on an hour-long journey through the saga and prepare you for the explosive final chapter: Star Wars: Episode III Revenge of the Sith.',
#   'popularity': 8.674,
#   'poster_path': '/fvw9W7ds0Q51hQIbS7JoUBqL3tK.jpg',
#   'release_date': '2004-08-18',
#   'title': 'The Story of Star Wars',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 20},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99, 878],
#   'id': 277499,
#   'original_language': 'en',
#   'original_title': 'From Star Wars to Star Wars: The Story of Industrial Light & Magic',
#   'overview': 'The incredible evolution of George Lucas\' special effects dream factory, including an inside look at "Star Wars: Episode One - The Phantom Menace."',
#   'popularity': 7.483,
#   'poster_path': '/eOK9FczS2GrH8ByZr9RkLYnQiW6.jpg',
#   'release_date': '1999-06-15',
#   'title': 'From Star Wars to Star Wars: The Story of Industrial Light & Magic',
#   'video': False,
#   'vote_average': 8.4,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': '/oXGUzdSHfEvzteQSn7Whgr0h0N6.jpg',
#   'genre_ids': [878, 16, 10751, 10770],
#   'id': 248931,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Droids - The Great Heep',
#   'overview': 'C-3PO and R2-D2 are on their way to Biitu to meet their new master, Mungo Baobab, when their ship is attacked and they are taken prisoner. Biitu has been taken over by the giant mechanical Great Heep who works with the Empire, enslaving the natives by using droid enforcers and draining R2 units to keep up his strength. Meanwhile Mungo has been imprisoned to be handed over to his arch enemy Admiral Screed.',
#   'popularity': 6.416,
#   'poster_path': '/rTylicBcqBI019WqCb835RmxMkk.jpg',
#   'release_date': '1986-06-07',
#   'title': 'Star Wars: Droids - The Great Heep',
#   'video': False,
#   'vote_average': 6.4,
#   'vote_count': 15},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 378386,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Greatest Moments',
#   'overview': 'Alex Zane counts down the top 20 Star Wars moments as voted by the public. Includes contributions from famous fans as well as the stars and crew of the intergalactic saga.',
#   'popularity': 7.294,
#   'poster_path': '/zIffPwISrW48qSmvAXEV27lBTMA.jpg',
#   'release_date': '2015-12-26',
#   'title': 'Star Wars: Greatest Moments',
#   'video': False,
#   'vote_average': 7.047,
#   'vote_count': 32},
#  {'adult': False,
#   'backdrop_path': '/drMhKqKimOvy8rNsKKJQGY2nZGk.jpg',
#   'genre_ids': [878],
#   'id': 949966,
#   'original_language': 'en',
#   'original_title': 'Untitled Star Wars "New Jedi Order" Film',
#   'overview': '15 years after the events of Star Wars: The Rise of Skywalker, Rey Skywalker rebuilds the Jedi Order.',
#   'popularity': 3.733,
#   'poster_path': None,
#   'release_date': '2026-12-18',
#   'title': 'Untitled Star Wars "New Jedi Order" Film',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 436621,
#   'original_language': 'fr',
#   'original_title': "Star Wars : L'incroyable Légende",
#   'overview': '',
#   'popularity': 0.819,
#   'poster_path': '/nsZIPT5pyvXHftO8bH4o7LU8Vch.jpg',
#   'release_date': '2015-11-25',
#   'title': "Star Wars : L'incroyable Légende",
#   'video': False,
#   'vote_average': 5.2,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': '/1Hhp0ys20V6I73Ph0MyhcDX2KOX.jpg',
#   'genre_ids': [99],
#   'id': 128295,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Legacy Revealed',
#   'overview': 'Film-makers and academics discuss the use of mythology in Star Wars and the impact of the films on society',
#   'popularity': 8.639,
#   'poster_path': '/r8DHOCDpZagHDNPt0K3O82ppGKx.jpg',
#   'release_date': '2007-05-28',
#   'title': 'Star Wars: The Legacy Revealed',
#   'video': False,
#   'vote_average': 7.225,
#   'vote_count': 40},
#  {'adult': False,
#   'backdrop_path': '/pmKhN5SsjI67OMbyMS4zaalGkk1.jpg',
#   'genre_ids': [10751, 14, 878, 16, 35],
#   'id': 81234,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars: Revenge of The Brick',
#   'overview': 'Anakin Skywalker and Obi-Wan Kenobi attempt to stop the Separatists from invading Kashyyyk. Meanwhile, Master Yoda must defeat an evil army of droids.',
#   'popularity': 6.411,
#   'poster_path': '/wi5IvbMRGD8fko6vv58NrogdJdd.jpg',
#   'release_date': '2005-08-05',
#   'title': 'LEGO Star Wars: Revenge of The Brick',
#   'video': False,
#   'vote_average': 5.9,
#   'vote_count': 30},
#  {'adult': False,
#   'backdrop_path': '/zLB78pH7SBtP5fDh2ggzhxxgkCn.jpg',
#   'genre_ids': [99, 10770],
#   'id': 35795,
#   'original_language': 'en',
#   'original_title': 'From Star Wars to Jedi: The Making of a Saga',
#   'overview': 'From Star Wars to Jedi: The Making of a Saga is a 1983 television documentary special that originally aired on PBS. It is a behind-the-scenes look at the making of the original Star Wars trilogy, with particular emphasis on the final film, Return of the Jedi. Narrated by actor Mark Hamill, the documentary was written by Richard Schickel who had written the previous television documentaries The Making of Star Wars (1977) and SP FX: The Empire Strikes Back (1980).',
#   'popularity': 9.758,
#   'poster_path': '/5TuxIPkudDni4BQDAIx8KCWgqZi.jpg',
#   'release_date': '1983-12-03',
#   'title': 'From Star Wars to Jedi: The Making of a Saga',
#   'video': False,
#   'vote_average': 7.1,
#   'vote_count': 18},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878],
#   'id': 1110063,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Dawn of the Jedi',
#   'overview': 'Set during the "Dawn of the Jedi" era, 25,000 years in the galaxy\'s past and described as a "Biblical epic" about "the dawning of the Force".',
#   'popularity': 3.864,
#   'poster_path': None,
#   'release_date': '',
#   'title': 'Star Wars: Dawn of the Jedi',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878, 28, 12],
#   'id': 700330,
#   'original_language': 'en',
#   'original_title': 'Untitled Taika Waititi Star Wars Film',
#   'overview': 'An untitled Star Wars film directed and co-written by Taika Waititi.',
#   'popularity': 3.696,
#   'poster_path': None,
#   'release_date': '',
#   'title': 'Untitled Taika Waititi Star Wars Film',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/aLdrVW80OrNQWxiqlU3N2dZJK8X.jpg',
#   'genre_ids': [99],
#   'id': 624371,
#   'original_language': 'en',
#   'original_title': "Star Wars: Galaxy's Edge - Adventure Awaits",
#   'overview': 'An exclusive behind-the-scenes look at the new lands at Walt Disney World Resort in Florida and Disneyland Resort in Southern California.',
#   'popularity': 4.824,
#   'poster_path': '/8YONsxklf7y2fnx8mOjNeWTgfPD.jpg',
#   'release_date': '2019-09-29',
#   'title': "Star Wars: Galaxy's Edge - Adventure Awaits",
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': '/1dzQeKE3COKrvBs6Q2heIKP4cmT.jpg',
#   'genre_ids': [99],
#   'id': 253150,
#   'original_language': 'en',
#   'original_title': 'Plastic Galaxy: The Story of Star Wars Toys',
#   'overview': "Plastic Galaxy explores the ground breaking and breathtaking world of 'Star Wars' toys. Through interviews with former Kenner employees, experts, authors, and collectors, the documentary looks at the toys' history, influence, and the passions they elicit today.",
#   'popularity': 9.824,
#   'poster_path': '/uJxlQhzz9gYDUvHJ6qaTc166JuZ.jpg',
#   'release_date': '2014-01-14',
#   'title': 'Plastic Galaxy: The Story of Star Wars Toys',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 26},
#  {'adult': False,
#   'backdrop_path': '/jTB8BKStGgIktED2yVMA6U6mppl.jpg',
#   'genre_ids': [10751, 16, 878, 35],
#   'id': 79158,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars: Bombad Bounty',
#   'overview': 'Darth Vader hires Boba Fett to track down Jar Jar Binks, who has caused a lot of trouble for Vader. This leads Binks and Fett on a game of cat-and-mouse like never seen before.',
#   'popularity': 3.823,
#   'poster_path': '/r088BCbLiSxccTHXxIZBZ5olRvM.jpg',
#   'release_date': '2010-11-27',
#   'title': 'LEGO Star Wars: Bombad Bounty',
#   'video': False,
#   'vote_average': 5.968,
#   'vote_count': 31},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 154452,
#   'original_language': 'en',
#   'original_title': 'Star Wars Tech',
#   'overview': 'Exploring the technical aspects of Star Wars vehicles, weapons and gadgetry, Star Wars Tech consults leading scientists in the fields of physics, prosthetics, lasers, engineering and astronomy to examine the plausibility of Star Wars technology based on science as we know it today.',
#   'popularity': 4.5,
#   'poster_path': '/7QzWbQnVaZwCwOkzhpXplERDbVF.jpg',
#   'release_date': '2007-05-28',
#   'title': 'Star Wars Tech',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 8},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99, 10770],
#   'id': 358536,
#   'original_language': 'en',
#   'original_title': 'When Star Wars Ruled the World',
#   'overview': 'A VH1 television special wherein the cast discuss the making of the films and what made the franchise a phenomenon.',
#   'popularity': 6.836,
#   'poster_path': '/qj2xUorXu1pxhXAFyNooGTlqAlT.jpg',
#   'release_date': '2004-09-18',
#   'title': 'When Star Wars Ruled the World',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 9},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [16, 28, 878],
#   'id': 1183093,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Squadrons - Hunted',
#   'overview': 'Stranded by his Star Destroyer, Varko Grey becomes the last TIE pilot on the battlefield, hunted by a renegade X-Wing of the New Republic.',
#   'popularity': 2.9,
#   'poster_path': '/6btSajiF8g70SoPRk9pB87kUHmR.jpg',
#   'release_date': '2020-09-14',
#   'title': 'Star Wars: Squadrons - Hunted',
#   'video': False,
#   'vote_average': 5.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/tZ62rwgGfK3ExfkVHepHWfsD1NV.jpg',
#   'genre_ids': [],
#   'id': 700448,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Clone Wars - The Nightsisters Trilogy',
#   'overview': 'A home video compilation film of the Star Wars: The Clone Wars episodes "Nightsisters," "Monster," and "Witches of the Mist," cut together. Originally shown at select screenings in 2010 (mainly at conventions), and it was published as an iTunes digital download on December 5, 2011.',
#   'popularity': 2.528,
#   'poster_path': '/sUNP79k7e5tTOVDoi5TaY866PkG.jpg',
#   'release_date': '2011-12-05',
#   'title': 'Star Wars: The Clone Wars - The Nightsisters Trilogy',
#   'video': True,
#   'vote_average': 9.2,
#   'vote_count': 5},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 778832,
#   'original_language': 'en',
#   'original_title': "WCCW Christmas Star Wars '85",
#   'overview': 'Witness a brutal battle when The Von Erichs clash with The Freebirds',
#   'popularity': 3.264,
#   'poster_path': None,
#   'release_date': '1985-12-25',
#   'title': "WCCW Christmas Star Wars '85",
#   'video': True,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [10751, 16],
#   'id': 292410,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Ewoks - Tales from the Endor Woods',
#   'overview': "Wicket remembers four memorable adventures from his youth: how he fixed up his great grandfather's battle wagon, the occasion when Latara ran away from the Ewok village to join the traveling Jindas, the time his father Deej fell terrible ill and the story of Kneesa's long lost sister, Asha.",
#   'popularity': 3.875,
#   'poster_path': '/owuYP5om2VYb9txYsveEEtuUZ2X.jpg',
#   'release_date': '1997-02-11',
#   'title': 'Star Wars: Ewoks - Tales from the Endor Woods',
#   'video': True,
#   'vote_average': 5.3,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 701034,
#   'original_language': 'fr',
#   'original_title': 'Star Wars : La Révolution Visuelle',
#   'overview': '',
#   'popularity': 1.873,
#   'poster_path': '/xlnSZTufBcVt0oLmp8fsKR3tKUp.jpg',
#   'release_date': '2020-05-04',
#   'title': 'Star Wars : La Révolution Visuelle',
#   'video': True,
#   'vote_average': 6.2,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/35JfUNTaFELC9iMoLTaLeGlok4V.jpg',
#   'genre_ids': [10402, 99],
#   'id': 72448,
#   'original_language': 'en',
#   'original_title': 'Star Wars: A Musical Journey',
#   'overview': "Star Wars: In Concert, originally called Star Wars: A Musical Journey, was a worldwide series of concerts featuring specially edited footage from all six of the Star Wars films (on the world's largest LED screen) set to live performances of John Williams' Star Wars score. The first performance took place in the O2 Arena in London, England. It was attended by 20,000 fans. The North American concerts started in Anaheim, California on October 1, 2009. The concerts were narrated by Anthony Daniels and conducted by Dirk Brosse. The concert took the audience through the Star Wars story line starting with Star Wars: Episode I The Phantom Menace and ending with Star Wars: Episode VI Return of the Jedi. The concert toured throughout the world extensively in 2009 and 2010, with an announced two-date engagement (June 3 and 4, 2011) at the Hollywood Bowl in 2011.",
#   'popularity': 3.028,
#   'poster_path': '/z9YDGgR5p34ODJj3N4uY7bHKU1.jpg',
#   'release_date': '2005-05-03',
#   'title': 'Star Wars: A Musical Journey',
#   'video': False,
#   'vote_average': 6.9,
#   'vote_count': 17},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 294822,
#   'original_language': 'en',
#   'original_title': 'Hollywood Rivals: Star Wars vs. Star Trek',
#   'overview': 'Star Wars vs. Star Trek. George Lucas, Liam Neeson, Samuel L. Jackson, Natalie Portman, Mark Hamill, Carrie Fisher and Harrison Ford share insights and the special effects creator compares the worlds of Star Trek and Star Wars.',
#   'popularity': 0.704,
#   'poster_path': '/tEacV6cPxe9nznaMkoZp3A6rAUQ.jpg',
#   'release_date': '2001-10-19',
#   'title': 'Hollywood Rivals: Star Wars vs. Star Trek',
#   'video': False,
#   'vote_average': 4.5,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 654663,
#   'original_language': 'en',
#   'original_title': 'Robot Chicken: Star Wars Trilogy',
#   'overview': 'All three of the Robot Chicken Star Wars specials (Episodes 1-3).',
#   'popularity': 0.342,
#   'poster_path': '/pSBmtqNBOe47ImbLWcAE7a2juNL.jpg',
#   'release_date': '2010-12-19',
#   'title': 'Robot Chicken: Star Wars Trilogy',
#   'video': True,
#   'vote_average': 7.0,
#   'vote_count': 2},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 1045923,
#   'original_language': 'en',
#   'original_title': 'Untitled Shawn Levy Star Wars Film',
#   'overview': 'An upcoming film in the Star Wars franchise developed and directed by Shawn Levy.',
#   'popularity': 3.387,
#   'poster_path': None,
#   'release_date': '',
#   'title': 'Untitled Shawn Levy Star Wars Film',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/wz6ifU1weVkK2whJWzm2pUgizhg.jpg',
#   'genre_ids': [99, 10770],
#   'id': 485997,
#   'original_language': 'en',
#   'original_title': 'Star Wars: The Magic & the Mystery',
#   'overview': 'Host Howie Long takes viewers on a tour of the "Star Wars" universe, as Fox TV celebrates the re-release of the original three legendary films in this one hour special.',
#   'popularity': 8.635,
#   'poster_path': '/8TKZNYSI62UxBxhrhDeFaiYbQki.jpg',
#   'release_date': '1997-02-06',
#   'title': 'Star Wars: The Magic & the Mystery',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878],
#   'id': 1110112,
#   'original_language': 'en',
#   'original_title': 'Untitled New Republic Era Star Wars Film',
#   'overview': 'Focuses on the escalating war between the Imperial Remnant and the fledgling New Republic, and serves as a culmination of interconnected stories from The Mandalorian, The Book of Boba Fett, and Ahsoka.',
#   'popularity': 3.23,
#   'poster_path': None,
#   'release_date': '',
#   'title': 'Untitled New Republic Era Star Wars Film',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 486000,
#   'original_language': 'en',
#   'original_title': 'The Characters of Star Wars',
#   'overview': 'The Characters of Star Wars is a Video Documentary included in the 2004 DVD release of the Star Wars Original Trilogy. It explained the Mythos of many of the "Star Wars" Characters.',
#   'popularity': 3.625,
#   'poster_path': '/kCo4AowrEKh4lZBCtgGNrGXPNli.jpg',
#   'release_date': '2004-09-21',
#   'title': 'The Characters of Star Wars',
#   'video': False,
#   'vote_average': 6.8,
#   'vote_count': 9},
#  {'adult': False,
#   'backdrop_path': '/a3v1rfjMUxMX7cgy5ytwYHIToVt.jpg',
#   'genre_ids': [10751, 16, 878, 35],
#   'id': 81233,
#   'original_language': 'en',
#   'original_title': 'LEGO Star Wars: The Quest for R2-D2',
#   'overview': 'When R2-D2 gets lost in space, Anakin Skywalker and his apprentice Ahsoka Tano set off on a mission to find their droid pal.',
#   'popularity': 6.425,
#   'poster_path': '/pfI6dMB5aplRYe7vSniDznnFWUx.jpg',
#   'release_date': '2009-08-28',
#   'title': 'LEGO Star Wars: The Quest for R2-D2',
#   'video': False,
#   'vote_average': 5.455,
#   'vote_count': 33},
#  {'adult': False,
#   'backdrop_path': '/n5dk0NXOkQyhRWirTHXe0xRV6vJ.jpg',
#   'genre_ids': [99],
#   'id': 363132,
#   'original_language': 'en',
#   'original_title': 'Star Wars Begins: A Filmumentary',
#   'overview': 'Filmmaker Jamie Benning has finally finished his trilogy of documentary-commentaries. This final chapter concentrates on the first Star Wars film. Like his two previous documentaries, Building Empire (2006) and Returning to Jedi (2007), Star Wars Begins is an unofficial look at the creation of the classic movie and features deleted scenes, alternate takes and different angles, bloopers, original on set audio recordings and a huge amount of commentary from cast and crew, culled from every corner of the galaxy.',
#   'popularity': 0.661,
#   'poster_path': '/hehyCpKYXBvirUaTx5SM9pe3gDa.jpg',
#   'release_date': '2011-02-02',
#   'title': 'Star Wars Begins: A Filmumentary',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 6},
#  {'adult': False,
#   'backdrop_path': '/zVMFlDKFOMDj1n3DNGBKCb0pHfZ.jpg',
#   'genre_ids': [16, 18, 10752, 36],
#   'id': 56316,
#   'original_language': 'ja',
#   'original_title': 'お星さまのレール',
#   'overview': "A young Japanese actress remembers her war childhood in Korea. Her father goes to fight, her baby sister Miko dies of typhoid, her beloved Korean maid Ohana is fired due to a mistake which could cost Chiko her life... By and by Chiko realizes that the country is being ruled by the Japanese and the Koreans are persecuted. When the war ends, the Koreans chase the Japanese rule and the roles change. Now Chiko's family is unwanted. But then the Russians come and this is the end. They have to burn all the pictures to avoid all suspicions... even Miko's picture. But when the Russians come to their house, they decide to flee over the 38th Parallel towards freedom. A group of men, women, children struggles along the mountains, led by the light of the Northern Star. Along the way they meet a Korean man, who is willing to help them to escape the Russian soldiers although his family was killed by the Japanese.",
#   'popularity': 5.928,
#   'poster_path': '/61SWBd7NjMXgCCakYqdVcyqwtQt.jpg',
#   'release_date': '1993-10-07',
#   'title': 'Rail of the Star - A True Story of Children and War',
#   'video': False,
#   'vote_average': 6.1,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 778612,
#   'original_language': 'en',
#   'original_title': "WCCW Christmas Star Wars '84",
#   'overview': 'Kerry Von Erich seeks revenge and The NWA World\'s Heavyweight Championship from "The Nature Boy" Ric Flair.',
#   'popularity': 3.047,
#   'poster_path': None,
#   'release_date': '1984-12-25',
#   'title': "WCCW Christmas Star Wars '84",
#   'video': True,
#   'vote_average': 7.5,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99, 10402],
#   'id': 219566,
#   'original_language': 'en',
#   'original_title': 'Star Wars: Music by John Williams',
#   'overview': 'BBC documentary. Witness John Williams composing the legendary score for The Empire Strikes Back and conducting the London Symphony Orchestra.',
#   'popularity': 5.983,
#   'poster_path': '/1meQ6cRrHK7eETjmD3uAdy5qTKY.jpg',
#   'release_date': '1980-05-18',
#   'title': 'Star Wars: Music by John Williams',
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 6},
#  {'adult': False,
#   'backdrop_path': '/koTIAW0gVUuQVzWBoFUcKX220Hn.jpg',
#   'genre_ids': [878, 10770],
#   'id': 584907,
#   'original_language': 'en',
#   'original_title': 'Star Fleet: The Thalian Space Wars',
# ...
#   'popularity': 2.275,
#   'poster_path': '/wyxMqATF0NT1URh1UG7UwcrxJGs.jpg',
#   'release_date': '2014-05-13',
#   'title': 'FC Dinamo: FC Red Star – The War of Liberation Began at Maksimir Stadium',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/n8O03dan1JgB7xhV7mdkQR6DQMD.jpg',
#   'genre_ids': [878, 12],
#   'id': 1162594,
#   'original_language': 'en',
#   'original_title': 'Star Tours',
#   'overview': 'Thanks to an incompetent pilot droid, a space tour to the moon of Endor is derailed and caught in the midst of a battle between the Empire and the Rebel Alliance.',
#   'popularity': 4.129,
#   'poster_path': '/dYmpQee2Svo6IcYH0wxhmaUcWyp.jpg',
#   'release_date': '1989-07-12',
#   'title': 'Star Tours',
#   'video': False,
#   'vote_average': 7.2,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': '/c6UZKwtnuwMEWcQzyrT9lXsyVXj.jpg',
#   'genre_ids': [12, 10751, 14, 878, 10770],
#   'id': 1884,
#   'original_language': 'en',
#   'original_title': 'The Ewok Adventure',
#   'overview': 'Wicket the Ewok and his friends agree to help two shipwrecked human children, Mace and Cindel, on a quest to find their parents.',
#   'popularity': 23.468,
#   'poster_path': '/c72Ix53KzxjHEv7IfnQbcQpMp0L.jpg',
#   'release_date': '1984-11-25',
#   'title': 'The Ewok Adventure',
#   'video': False,
#   'vote_average': 5.897,
#   'vote_count': 349},
#  {'adult': False,
#   'backdrop_path': '/xdH8k2O6mpLv4szeLkQGiM1aSOC.jpg',
#   'genre_ids': [12, 10751, 10770, 878, 14],
#   'id': 10372,
#   'original_language': 'en',
#   'original_title': 'Ewoks: The Battle for Endor',
#   'overview': "The army of the Marauders, led by King Terak and the witch Charal, attack the Ewoks village, killing Cindel's family. Cindel and the Ewok Wicket escape and meet Teek in the forest, a naughty and very fast animal. Teek takes them to a house in which an old man, Noa, lives. Like Cindel, he also crashed with his Starcruiser on Endor. Together they fight Terak and Charal.",
#   'popularity': 28.571,
#   'poster_path': '/5IKAgTQ9CbVbJY56v51cnA9qhNZ.jpg',
#   'release_date': '1985-11-24',
#   'title': 'Ewoks: The Battle for Endor',
#   'video': False,
#   'vote_average': 5.393,
#   'vote_count': 284},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878],
#   'id': 1178539,
#   'original_language': 'en',
#   'original_title': 'Lando',
#   'overview': "A spin-off of Solo: A Star Wars Story, featuring Donald Glover's Lando Calrissian in the leading role.",
#   'popularity': 2.539,
#   'poster_path': '/fO07NjZ3d28LAacAxEJZwsvR4o2.jpg',
#   'release_date': '',
#   'title': 'Lando',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/4BEq0oCymQwMeGykhmglBxm1IEG.jpg',
#   'genre_ids': [99],
#   'id': 513696,
#   'original_language': 'en',
#   'original_title': 'Balance of the Force',
#   'overview': 'Explore the mythology of the Force and why Rian Johnson chose to interpret its role in such a unique way.',
#   'popularity': 5.013,
#   'poster_path': '/rbACfiyqoiPd0TbDyhPe2qdlmve.jpg',
#   'release_date': '2018-03-12',
#   'title': 'Balance of the Force',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 4},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 435147,
#   'original_language': 'en',
#   'original_title': "From Puppets to Pixels: Digital Characters in 'Episode II'",
#   'overview': 'For Star Wars: Episode II - Attack of the Clones (2002), there were to be many more visual effects than in Star Wars: Episode I - The Phantom Menace (1999). This documentary shows many VFX meetings between George Lucas and ILM. Many of these meetings focus around the creation of a completely digital Yoda, used for the first time in the Star Wars films.',
#   'popularity': 9.208,
#   'poster_path': '/tT0UyqN2SH2s9Qay3Nk10AEmgNR.jpg',
#   'release_date': '2002-11-12',
#   'title': "From Puppets to Pixels: Digital Characters in 'Episode II'",
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 9},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 407001,
#   'original_language': 'en',
#   'original_title': 'Star Warriors',
#   'overview': 'Some Star Wars fans want to collect action figures... these fans want to be action figures! A tribute to the 501st Legion, a global organization of Star Wars costume enthusiasts, this insightful documentary shows how the super-fan club promotes interest in the films through charity and volunteer work at fundraisers and high-profile special events around the world.',
#   'popularity': 2.991,
#   'poster_path': '/64cqANu2XUWnqv9f4CaKHbMazD4.jpg',
#   'release_date': '2007-01-01',
#   'title': 'Star Warriors',
#   'video': False,
#   'vote_average': 5.8,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/yMXP2ZXgfqnFxDg5y1Pb5xohLRE.jpg',
#   'genre_ids': [28, 878],
#   'id': 24551,
#   'original_language': 'it',
#   'original_title': 'Dark Resurrection',
#   'overview': 'An ancient prophesy convinces the powerful Master Sorran to commence an obsessive search for Eron, a mythical place capable of giving the Chosen One infinite knowledge.',
#   'popularity': 3.647,
#   'poster_path': '/voyuEfN4KRUF5s7pX3b1AK6Qmfc.jpg',
#   'release_date': '2007-06-07',
#   'title': 'Dark Resurrection',
#   'video': False,
#   'vote_average': 6.0,
#   'vote_count': 21},
#  {'adult': False,
#   'backdrop_path': '/kdYMNlpycbN1XoZMPzwRIr0BavH.jpg',
#   'genre_ids': [878, 28],
#   'id': 131477,
#   'original_language': 'it',
#   'original_title': 'Dark Resurrection Volume 0',
#   'overview': "Master Sorran is obsessed by his search for an ancient civilization which, according to legend, holds the secret of immortality. After many years he lights upon the wreck of the civilisation's most powerful starship: the Resurrection. Sorran ignores the dangers and orders his crew to dock. The explorers and Sorran himself will face the mysteries of the Resurrection and the secret of the origins of the dark side.",
#   'popularity': 4.515,
#   'poster_path': '/ujrDzT9DYRjUUaTh71KbN6L7XBo.jpg',
#   'release_date': '2011-09-08',
#   'title': 'Dark Resurrection Volume 0',
#   'video': False,
#   'vote_average': 6.2,
#   'vote_count': 10},
#  {'adult': False,
#   'backdrop_path': '/bjp1gezn4DzP8juI3ZvjN4uPlsK.jpg',
#   'genre_ids': [99, 35, 9648],
#   'id': 638738,
#   'original_language': 'en',
#   'original_title': 'The Empire Strikes Door',
#   'overview': 'A thrilling comedic documentary attempting to uncover the mystery of who is responsible for one of the most infamous bloopers in cinematic history.',
#   'popularity': 3.406,
#   'poster_path': '/mRGS7AdkSOBTGNdfD5Q5TusHtez.jpg',
#   'release_date': '2019-09-25',
#   'title': 'The Empire Strikes Door',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/AkuDVdvopWHr2Vw3IBmfhlPk8Bx.jpg',
#   'genre_ids': [99],
#   'id': 110354,
#   'original_language': 'en',
#   'original_title': 'Side by Side',
#   'overview': 'Since the invention of cinema, the standard format for recording moving images has been film. Over the past two decades, a new form of digital filmmaking has emerged, creating a groundbreaking evolution in the medium. Keanu Reeves explores the development of cinema and the impact of digital filmmaking via in-depth interviews with Hollywood masters, such as James Cameron, David Fincher, David Lynch, Christopher Nolan, Martin Scorsese, George Lucas, Steven Soderbergh, and many more.',
#   'popularity': 20.041,
#   'poster_path': '/qeeQ7rfTAXNYh4EqqdolFLkNwKM.jpg',
#   'release_date': '2012-08-19',
#   'title': 'Side by Side',
#   'video': False,
#   'vote_average': 7.256,
#   'vote_count': 285},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [12, 28],
#   'id': 1233860,
#   'original_language': 'en',
#   'original_title': 'Rogue Squadron',
#   'overview': 'A new generation of starfighter pilots earn their wings and risk their lives in a boundary-pushing, high-speed thrill-ride, and move the Star Wars saga into the future era of the galaxy.',
#   'popularity': 1.202,
#   'poster_path': '/3CZTfo5h9OmGKf1t2dETV99xo5j.jpg',
#   'release_date': '',
#   'title': 'Rogue Squadron',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [35, 878, 28, 12],
#   'id': 31279,
#   'original_language': 'tr',
#   'original_title': 'Dünyayı Kurtaran Adamın Oğlu',
#   'overview': 'The year is 2055, and the universe is in a state of turmoil, awaiting the formation of a government that can establish universal peace. Until such a time, the Orion Union stands in its stead, an uneasy alliance made up not of planets, but of their individual states, overlorded by unruly gangs, short-sighted tyrants and hissing, domineering queens. In short, chaos reigns.',
#   'popularity': 8.799,
#   'poster_path': '/zdisSUrAWY2M01svivJDV048cD1.jpg',
#   'release_date': '2006-12-14',
#   'title': 'Turks in Space',
#   'video': False,
#   'vote_average': 2.313,
#   'vote_count': 48},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [99],
#   'id': 507052,
#   'original_language': 'en',
#   'original_title': 'The Force of Sound',
#   'overview': 'Go inside the sound design of Star Wars: The Last Jedi. From the ignition of a lightsaber to the chirp of a porg, Star Wars would not be the same without the brilliant sound design and mixing created by Skywalker Sound.',
#   'popularity': 3.678,
#   'poster_path': '/q41hKQWdZVoGx4aNd8Ul2oFeaBW.jpg',
#   'release_date': '2018-02-20',
#   'title': 'The Force of Sound',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/dC4sccm4BYwCeP4tvpEM4B8TfNC.jpg',
#   'genre_ids': [99],
#   'id': 363140,
#   'original_language': 'en',
#   'original_title': 'Returning to Jedi: A Filmumentary',
#   'overview': 'Returning to Jedi is an in-depth look at the making of Star Wars: Episode VI - Return of the Jedi. It features rare alternate takes, production audio, on-screen facts, cast and crew commentary, storyboards, behind the scenes footage and reconstructed scenes.',
#   'popularity': 1.048,
#   'poster_path': '/iAhJ1eAVZ6xPdqyDz9m769KVRWm.jpg',
#   'release_date': '2007-01-20',
#   'title': 'Returning to Jedi: A Filmumentary',
#   'video': False,
#   'vote_average': 6.7,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/b0ueueCWrTs3W3XTZmbh3qL8VtL.jpg',
#   'genre_ids': [99],
#   'id': 363139,
#   'original_language': 'en',
#   'original_title': 'Building Empire: A Filmumentary',
#   'overview': 'Building Empire is an unofficial commentary on The Empire Strikes Back. Starting with the movie itself, it adds behind the scenes footage, audio interviews with the cast and crew, alternate angles, reconstructed scenes, text facts and more to give an in-depth look at the process which brought the film to the big screen.',
#   'popularity': 0.736,
#   'poster_path': '/dqxCRedUgjCmnNJ18ZBxurpKVLd.jpg',
#   'release_date': '2006-03-02',
#   'title': 'Building Empire: A Filmumentary',
#   'video': False,
#   'vote_average': 7.0,
#   'vote_count': 1},
#  {'adult': False,
#   'backdrop_path': '/vMqmtmCtdLmPE43EiLk0I7wGSQV.jpg',
#   'genre_ids': [12, 35, 10751, 878],
#   'id': 42209,
#   'original_language': 'pt',
#   'original_title': 'Os Trapalhões na Guerra dos Planetas',
#   'overview': "Coming from outer space, Prince Flick asks the Trapalhões to help him free his planet from the domain of evil Zuco and free Princess Myrna, who has been taken prisoner. He offers a reward, the four friends accept the mission and embark in a spaceship driven by a hairy monster called Bonzo. Once on the planet, they they defeat Zuco, but they fail to save Princess Myrna's life. Her place on the throne is then taken by Loya, the girlfriend Didi met on that planet. Back on Earth, os Trapalhões think their adventure was but a dream, but they are convinced otherwise when they find their reward.",
#   'popularity': 3.715,
#   'poster_path': '/7YKkoRpSsrCVeNoWVEEDoenrCnP.jpg',
#   'release_date': '1978-03-26',
#   'title': 'The Bunglers in the Planet Wars',
#   'video': False,
#   'vote_average': 4.8,
#   'vote_count': 34},
#  {'adult': False,
#   'backdrop_path': '/e00Ptx0nyfKjXallrNMVdzTLPDY.jpg',
#   'genre_ids': [99],
#   'id': 65083,
#   'original_language': 'en',
#   'original_title': "The Beginning: Making 'Episode I'",
#   'overview': "The entire process of making Star Wars: Episode I - The Phantom Menace (1999) is shown here in this documentary. From pre-production through post-production, we get to see visual effects meetings, John Williams' music sessions, and even the storm that wiped out the pod-racers & props.",
#   'popularity': 8.365,
#   'poster_path': '/rW9HI8iL50RjmQIgyZvlfor5K4Y.jpg',
#   'release_date': '2001-10-16',
#   'title': "The Beginning: Making 'Episode I'",
#   'video': False,
#   'vote_average': 7.3,
#   'vote_count': 25},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [878, 14],
#   'id': 1250432,
#   'original_language': 'en',
#   'original_title': 'Hoshino',
#   'overview': 'The tale of blind Jedi Master Ko Hoshino and her journey to becoming one with the Force.',
#   'popularity': 1.583,
#   'poster_path': '/9SEC9RtZhxtCcrDSbv8q5neeIrV.jpg',
#   'release_date': '2016-11-01',
#   'title': 'Hoshino',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0},
#  {'adult': False,
#   'backdrop_path': '/sBrPd8pn50z8FDhfEAMBykTEdQO.jpg',
#   'genre_ids': [99],
#   'id': 443412,
#   'original_language': 'en',
#   'original_title': 'Ralph McQuarrie: Tribute to a Master',
#   'overview': 'Ralph McQuarrie, concept artist of the original Star Wars trilogy, was essential in bringing the characters, ships, and locales of a galaxy far, far away to life. In this special retrospective, Star Wars creator George Lucas, Industrial Light & Magic effects legend Dennis Muren, and many others discuss the impact of McQuarrie, his artistic gifts, and his legacy.',
#   'popularity': 2.962,
#   'poster_path': '/msQwsqpfiJ1JL9x2poqUgYJvcOS.jpg',
#   'release_date': '2014-03-05',
#   'title': 'Ralph McQuarrie: Tribute to a Master',
#   'video': False,
#   'vote_average': 9.3,
#   'vote_count': 3},
#  {'adult': False,
#   'backdrop_path': '/8c0UveXrXrUay4bjIBlAuFpkNS.jpg',
#   'genre_ids': [10402],
#   'id': 922333,
#   'original_language': 'en',
#   'original_title': 'John Williams & Berliner Philharmoniker - The Berlin Concert',
#   'overview': 'John Williams has made cinematic history with his film scores and transported entire generations into his musical worlds. He has composed the soundtracks for cinema blockbusters such as "Star Wars", "Jurassic Park", "E.T." and "Harry Potter". In this concert, he conducts some of his most famous film classics. At the same time, this is his debut on the podium of the Berliner Philharmoniker. May the Force be with him ...',
#   'popularity': 3.534,
#   'poster_path': '/nvWcU9aO7eqcnvZG6VP4LxKGjDr.jpg',
#   'release_date': '2022-02-04',
#   'title': 'John Williams & Berliner Philharmonic - The Berlin Concert',
#   'video': False,
#   'vote_average': 6.6,
#   'vote_count': 7},
#  {'adult': False,
#   'backdrop_path': '/vys9PaP6EtjAXEKwGtpVXmeklps.jpg',
#   'genre_ids': [878, 28, 12, 14],
#   'id': 20787,
#   'original_language': 'tr',
#   'original_title': 'Dünyayı Kurtaran Adam',
#   'overview': 'Two space cadets crash-land on a desert planet, where an evil wizard seeks the ultimate power to take over the world. Although the movie borrows some background footage from Star Wars, the plot is mostly unrelated.',
#   'popularity': 6.871,
#   'poster_path': '/ksastHJy9zFIAtoPhosU4gsrHSV.jpg',
#   'release_date': '1982-11-04',
#   'title': 'The Man Who Saved the World',
#   'video': False,
#   'vote_average': 4.866,
#   'vote_count': 101},
#  {'adult': False,
#   'backdrop_path': None,
#   'genre_ids': [],
#   'id': 1264260,
#   'original_language': 'ko',
#   'original_title': '손오공과 별들의 전쟁',
#   'overview': '',
#   'popularity': 0.001,
#   'poster_path': '/m9bHBVTOYWK97ys3hhLOD1F9qrW.jpg',
#   'release_date': '1979-07-21',
#   'title': '손오공과 별들의 전쟁',
#   'video': False,
#   'vote_average': 0.0,
#   'vote_count': 0}]

# %%
allswdf = pd.DataFrame(all_starwars)
allswdf
# Out:
#      adult                     backdrop_path          genre_ids       id  \
# 0    False  /jNjT5y95BToczcxgVPl1NBB7goY.jpg      [12, 28, 878]       11
# 1    False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg      [12, 28, 878]   140607
# 2    False  /epVMXf10WqFkONzKR8V76Ypj5Y3.jpg      [12, 28, 878]   181808
# 3    False  /ojHCeDULAkQK25700fhRU75Tur2.jpg      [878, 12, 28]   348350
# 4    False  /jn52me8AagfNt7r84SgQbV0R9ZG.jpg      [12, 28, 878]   181812
# ..     ...                               ...                ...      ...
# 177  False                              None          [878, 14]  1250432
# 178  False  /sBrPd8pn50z8FDhfEAMBykTEdQO.jpg               [99]   443412
# 179  False   /8c0UveXrXrUay4bjIBlAuFpkNS.jpg            [10402]   922333
# 180  False  /vys9PaP6EtjAXEKwGtpVXmeklps.jpg  [878, 28, 12, 14]    20787
# 181  False                              None                 []  1264260
#
#     original_language                                     original_title  \
# 0                  en                                          Star Wars
# 1                  en                       Star Wars: The Force Awakens
# 2                  en                           Star Wars: The Last Jedi
# 3                  en                            Solo: A Star Wars Story
# 4                  en                   Star Wars: The Rise of Skywalker
# ..                ...                                                ...
# 177                en                                            Hoshino
# 178                en               Ralph McQuarrie: Tribute to a Master
# 179                en  John Williams & Berliner Philharmoniker - The ...
# 180                tr                              Dünyayı Kurtaran Adam
# 181                ko                                        손오공과 별들의 전쟁
#
#                                               overview  popularity  \
# 0    Princess Leia is captured and held hostage by ...     143.146
# 1    Thirty years after defeating the Galactic Empi...      90.923
# 2    Rey develops her newly discovered abilities wi...      82.350
# 3    Through a series of daring escapades deep with...      51.576
# 4    The surviving Resistance faces the First Order...      82.393
# ..                                                 ...         ...
# 177  The tale of blind Jedi Master Ko Hoshino and h...       1.583
# 178  Ralph McQuarrie, concept artist of the origina...       2.962
# 179  John Williams has made cinematic history with ...       3.534
# 180  Two space cadets crash-land on a desert planet...       6.871
# 181                                                          0.001
#
#                           poster_path release_date  \
# 0    /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 1    /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg   2015-12-15
# 2    /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg   2017-12-13
# 3    /4oD6VEccFkorEBTEDXtpLAaz0Rl.jpg   2018-05-15
# 4    /db32LaOibwEliAmSL2jjDF6oDdj.jpg   2019-12-18
# ..                                ...          ...
# 177  /9SEC9RtZhxtCcrDSbv8q5neeIrV.jpg   2016-11-01
# 178  /msQwsqpfiJ1JL9x2poqUgYJvcOS.jpg   2014-03-05
# 179  /nvWcU9aO7eqcnvZG6VP4LxKGjDr.jpg   2022-02-04
# 180  /ksastHJy9zFIAtoPhosU4gsrHSV.jpg   1982-11-04
# 181  /m9bHBVTOYWK97ys3hhLOD1F9qrW.jpg   1979-07-21
#
#                                                  title  video  vote_average  \
# 0                                            Star Wars  False         8.203
# 1                         Star Wars: The Force Awakens  False         7.278
# 2                             Star Wars: The Last Jedi  False         6.799
# 3                              Solo: A Star Wars Story  False         6.562
# 4                     Star Wars: The Rise of Skywalker  False         6.326
# ..                                                 ...    ...           ...
# 177                                            Hoshino  False         0.000
# 178               Ralph McQuarrie: Tribute to a Master  False         9.300
# 179  John Williams & Berliner Philharmonic - The Be...  False         6.600
# 180                        The Man Who Saved the World  False         4.866
# 181                                        손오공과 별들의 전쟁  False         0.000
#
#      vote_count
# 0       20283.0
# 1       19090.0
# 2       15010.0
# 3        8345.0
# 4        9676.0
# ..          ...
# 177         0.0
# 178         3.0
# 179         7.0
# 180       101.0
# 181         0.0
#
# [182 rows x 14 columns]

# %%
all_sw_json = pd.DataFrame(.json()['results'])
all_sw_json
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 all_sw_json = pd.DataFrame(all_sw_jsonstr.json()['results'])
#       2 all_sw_json
#
# AttributeError: 'str' object has no attribute 'json'

# %%
starwars_df.sort_values(by='popularity', ascending=False)
# Out:
#     adult                     backdrop_path                        genre_ids  \
# 0   False  /jNjT5y95BToczcxgVPl1NBB7goY.jpg                    [12, 28, 878]
# 5   False  /8mTHUXS3vwub5ZlovQkZ8veQUah.jpg                    [28, 12, 878]
# 1   False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg                    [12, 28, 878]
# 2   False  /epVMXf10WqFkONzKR8V76Ypj5Y3.jpg                    [12, 28, 878]
# 4   False  /jn52me8AagfNt7r84SgQbV0R9ZG.jpg                    [12, 28, 878]
# 6   False  /aQX9Hc4pCdbkzf4Oz6FMSpujagV.jpg                    [12, 28, 878]
# 8   False  /3TeGmKJfkik1D1rIoqGb1aR4k9c.jpg                    [12, 28, 878]
# 3   False  /ojHCeDULAkQK25700fhRU75Tur2.jpg                    [878, 12, 28]
# 10  False  /abwxHfymXGAbbH3lo9PDEJEfvtW.jpg                    [12, 28, 878]
# 13  False  /eVA4ztLIuPEsokkgQ3NRt9rTRVh.jpg                [16, 28, 878, 12]
# 7   False  /f53Jujiap580mgfefID0T0g2e17.jpg      [16, 10751, 878, 35, 10770]
# 9   False  /iflKt34Ck2JpY2PY9wW1zwdJgJi.jpg             [16, 878, 12, 10751]
# 19  False  /7nHXstkbnX8t7fKICraMJkuPhK5.jpg          [14, 878, 10751, 10770]
# 14  False  /1Lhc32P0a62BgMFgd20wXR1osR3.jpg         [16, 10751, 878, 12, 35]
# 12  False  /uNjBnOmdjZoiWTLQ938YJZ1cYVU.jpg  [16, 35, 10751, 878, 12, 10770]
# 11  False  /wBBONMlfnrU2GxxN7X2pFDdZuRB.jpg         [16, 12, 10751, 14, 878]
# 17  False  /l3OSKCM0oBOGuioC2jeaeeV8m4I.jpg         [16, 35, 878, 28, 10770]
# 15  False                              None                             [99]
# 16  False                              None                             [99]
# 18  False  /98CXGiN2bIh6HUnRjFNGgA9o4FZ.jpg                             [99]
#
#         id original_language                                original_title  \
# 0       11                en                                     Star Wars
# 5   330459                en                  Rogue One: A Star Wars Story
# 1   140607                en                  Star Wars: The Force Awakens
# 2   181808                en                      Star Wars: The Last Jedi
# 4   181812                en              Star Wars: The Rise of Skywalker
# 6     1895                en  Star Wars: Episode III - Revenge of the Sith
# 8     1893                en     Star Wars: Episode I - The Phantom Menace
# 3   348350                en                       Solo: A Star Wars Story
# 10    1894                en  Star Wars: Episode II - Attack of the Clones
# 13   12180                en                     Star Wars: The Clone Wars
# 7   857702                en               LEGO Star Wars Terrifying Tales
# 9   782054                ja                        映画ドラえもん のび太の宇宙小戦争 2021
# 19   74849                en                 The Star Wars Holiday Special
# 14  732670                en                LEGO Star Wars Holiday Special
# 12  392216                en                   Phineas and Ferb: Star Wars
# 11  161704                ja                               ドラえもん のび太の宇宙小戦争
# 17   42979                en                      Robot Chicken: Star Wars
# 15  432134                en                  Star Wars: Heroes & Villains
# 16  522640                es        Criaturas de La guerra de las galaxias
# 18  956879                fr                 Dans l’ombre du Star Wars Kid
#
#                                              overview  popularity  \
# 0   Princess Leia is captured and held hostage by ...     150.916
# 5   A rogue band of resistance fighters unite for ...      97.817
# 1   Thirty years after defeating the Galactic Empi...      88.529
# 2   Rey develops her newly discovered abilities wi...      84.642
# 4   The surviving Resistance faces the First Order...      75.839
# 6   The evil Darth Sidious enacts his final plan f...      62.334
# 8   Anakin Skywalker, a young slave strong with th...      53.170
# 3   Through a series of daring escapades deep with...      52.474
# 10  Following an assassination attempt on Senator ...      45.470
# 13  As the Clone Wars sweep through the galaxy, th...      22.813
# 7   Poe Dameron and BB-8 must face the greedy crim...      22.366
# 9   One day during summer vacation, a palm-sized a...      20.517
# 19  Luke Skywalker and Han Solo battle evil Imperi...      19.477
# 14  As her friends prep for a Life Day holiday cel...      16.452
# 12  Phineas and Ferb become the galaxy's unlikelie...      15.693
# 11  Nobita helps Doraemon to create a space movie....      15.305
# 17  A series of 30 sketches, following the hilario...      10.037
# 15  A look at the creation and filming of the vari...       4.023
# 16                                                          2.226
# 18  Ghyslain Raza, better known as the “Star Wars ...       1.357
#
#                          poster_path release_date  \
# 0   /6FfCtAuVAW8XJjZ7eWeLibRLWTw.jpg   1977-05-25
# 5   /i0yw1mFbB7sNGHCs7EXZPzFkdA1.jpg   2016-12-14
# 1   /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg   2015-12-15
# 2   /kOVEVeg59E0wsnXmF9nrh6OmWII.jpg   2017-12-13
# 4   /db32LaOibwEliAmSL2jjDF6oDdj.jpg   2019-12-18
# 6   /xfSAoBEm9MNBjmlNcDYLvLSMlnq.jpg   2005-05-17
# 8   /6wkfovpn7Eq8dYNKaG5PY3q2oq6.jpg   1999-05-19
# 3   /4oD6VEccFkorEBTEDXtpLAaz0Rl.jpg   2018-05-15
# 10  /oZNPzxqM2s5DyVWab09NTQScDQt.jpg   2002-05-15
# 13  /iJQfixW818LUdSXlCDL3JZm0S0g.jpg   2008-08-05
# 7   /fYiaBZDjyXjvlY6EDZMAxIhBO1I.jpg   2021-10-01
# 9   /48gKZioIDeUOI0afbYv3kh9u9RQ.jpg   2022-03-04
# 19  /2X17DnEtlI6ULf95wXC6sA4GrlL.jpg   1978-11-17
# 14  /zyzJSI7UZZzz5Toj10rYGF5689z.jpg   2020-11-17
# 12  /2XGlp5x232CeZM0PVjMMYQcXViA.jpg   2014-07-26
# 11  /n4IPqrfXEEtMC8hzV5PaCElkdNP.jpg   1985-03-16
# 17  /h44WN4mVJ6wEpJgLaaNoFjv0NAo.jpg   2007-07-17
# 15  /9ReI6qt3bvsIxUZkDpOzaCpiLwx.jpg   2005-05-03
# 16                              None   2006-12-12
# 18  /zspMlOFJ76g5KyfmucgnvnkJnuN.jpg   2022-03-30
#
#                                                 title  video  vote_average  \
# 0                                           Star Wars  False         8.200
# 5                        Rogue One: A Star Wars Story  False         7.500
# 1                        Star Wars: The Force Awakens  False         7.300
# 2                            Star Wars: The Last Jedi  False         6.800
# 4                    Star Wars: The Rise of Skywalker  False         6.300
# 6        Star Wars: Episode III - Revenge of the Sith  False         7.430
# 8           Star Wars: Episode I - The Phantom Menace  False         6.554
# 3                             Solo: A Star Wars Story  False         6.600
# 10       Star Wars: Episode II - Attack of the Clones  False         6.600
# 13                          Star Wars: The Clone Wars  False         6.126
# 7                     LEGO Star Wars Terrifying Tales  False         6.802
# 9   Doraemon the Movie: Nobita's Little Star Wars ...  False         5.900
# 19                      The Star Wars Holiday Special  False         3.337
# 14                     LEGO Star Wars Holiday Special  False         6.523
# 12                        Phineas and Ferb: Star Wars  False         7.152
# 11                Doraemon: Nobita's Little Star Wars  False         6.878
# 17                           Robot Chicken: Star Wars  False         7.223
# 15                       Star Wars: Heroes & Villains  False         7.200
# 16                           Creatures from Star Wars  False         4.000
# 18     Star Wars Kid: The Rise of the Digital Shadows  False         7.600
#
#     vote_count
# 0        20274
# 5        15005
# 1        19087
# 2        15006
# 4         9672
# 6        13452
# 8        14341
# 3         8342
# 10       12984
# 13        1958
# 7          239
# 9          106
# 19         445
# 14         311
# 12         197
# 11          37
# 17         242
# 15          20
# 16           2
# 18           9

# %%
tmdb.API_KEY = "69e0d756f57f03c3427c9622298bc4dc"
tmdb.REQUESTS_SESSION = requests.Session()

# %%
search = tmdb.Search()
response = search.movie(query='Star Wars')
date = {}
for m in search.results:
    data[m['title']] = m['popularity']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3 date = {}
#       4 for m in search.results:
# ----> 5     data[m['title']] = m['popularity']
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Out:
# ('The Star Wars Holiday Special', 74849, '1978-11-17', 19.477)
